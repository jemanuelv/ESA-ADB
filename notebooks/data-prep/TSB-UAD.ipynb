# %% [markdown]
# # TSB-UAD: An End-to-End Benchmark Suite for Univariate Time-Series Anomaly Detection
#
# - Source and description: https://github.com/TheDatumOrg/TSB-UAD
# - Paper: https://dl.acm.org/doi/pdf/10.14778/3529337.3529354

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from config import data_raw_folder, data_processed_folder
from timeeval import DatasetManager, Datasets
from timeeval.datasets import DatasetAnalyzer, DatasetRecord

# %%
plt.rcParams["figure.figsize"] = (20, 10)

# %%
def find_datasets(folder):
    if not isinstance(folder, Path):
        folder = Path(folder)
    return sorted([f for f in folder.glob("*.out") if f.is_file()])

# %%
dataset_collection_name = "TSB-UAD"
source_folder = Path(data_raw_folder) / "TSB-UAD"
target_folder = Path(data_processed_folder)

print(f"Looking for source datasets in {Path(source_folder).absolute()} and\nsaving processed datasets in {Path(target_folder).absolute()}")
# Out:
# Looking for source datasets in /home/projects/akita/data/benchmark-data/data-raw/TSB-UAD and
# saving processed datasets in /home/projects/akita/data/benchmark-data/data-processed

# %%
# shared by all datasets
dataset_type = "synthetic"
input_type = "univariate"
datetime_index = False
split_at = None
train_is_normal = False
train_type = "unsupervised"

dm = DatasetManager(target_folder, create_if_missing=False)

# %%
def process_dataset(dm: DatasetManager, idx: int, f: Path, name_prefix: str = "") -> None:
    print(f"> Processing source dataset {idx}")
    dataset_name = f"{name_prefix}-{f.stem}"
    test_filename = f"{dataset_name}.test.csv"
    test_path = dataset_subfolder / test_filename
    target_test_filepath = target_subfolder / test_filename
    target_meta_filepath = target_test_filepath.parent / f"{dataset_name}.{Datasets.METADATA_FILENAME_SUFFIX}"

    # Prepare datasets
    if not target_test_filepath.exists() or not target_meta_filepath.exists():
        df_test = pd.read_csv(f, header=None)
        df_test.columns = ["value", "is_anomaly"]
        df_test.insert(0, "timestamp", df_test.index)
        df_test.to_csv(target_test_filepath, index=False)
        print(f"  written dataset {idx}")
    else:
        df_test = None
        print(f"  skipped writing dataset {idx} to disk, because it already exists.")

    # Prepare metadata
    def analyze(df_test):
        da = DatasetAnalyzer((dataset_collection_name, dataset_name), is_train=False, df=df_test)
        da.save_to_json(target_meta_filepath, overwrite=True)
        meta = da.metadata
        print(f"  analyzed test dataset {idx}")
        return meta

    if target_meta_filepath.exists():
        try:
            meta = DatasetAnalyzer.load_from_json(target_meta_filepath, train=False)
            print(f"  skipped analyzing dataset {idx}, because metadata already exists.")
        except ValueError:
            if df_test is None:
                df_test = pd.read_csv(target_test_filepath)
            meta = analyze(df_test)
    else:
        meta = analyze(df_test)

    dm.add_dataset(DatasetRecord(
          collection_name=dataset_collection_name,
          dataset_name=dataset_name,
          train_path=None,
          test_path=test_path,
          dataset_type=dataset_type,
          datetime_index=datetime_index,
          split_at=split_at,
          train_type=train_type,
          train_is_normal=train_is_normal,
          input_type=input_type,
          length=meta.length,
          dimensions=meta.dimensions,
          contamination=meta.contamination,
          num_anomalies=meta.num_anomalies,
          min_anomaly_length=meta.anomaly_length.min,
          median_anomaly_length=meta.anomaly_length.median,
          max_anomaly_length=meta.anomaly_length.max,
          mean=meta.mean,
          stddev=meta.stddev,
          trend=meta.trend,
          stationarity=meta.get_stationarity_name(),
          period_size=np.nan
    ))
    print(f"... processed source dataset {idx}: {name_prefix}-{f.name} -> {target_test_filepath}")

subcollection = "artificial"

print("#############")
print(f"# Processing sub-collection {subcollection}")
print("#############")

# create target directory
dataset_subfolder = Path(input_type) / f"{dataset_collection_name}-{subcollection}"
target_subfolder = target_folder / dataset_subfolder
target_subfolder.mkdir(parents=True, exist_ok=True)
print(f"Created directories {target_subfolder}")

folder = source_folder / subcollection

i = 0
for file in find_datasets(folder):
    process_dataset(dm, i, file)
    i += 1
dm.save()


subcollection = "synthetic"

print("#############")
print(f"# Processing sub-collection {subcollection}")
print("#############")

# create target directory
dataset_subfolder = Path(input_type) / f"{dataset_collection_name}-{subcollection}"
target_subfolder = target_folder / dataset_subfolder
target_subfolder.mkdir(parents=True, exist_ok=True)
print(f"Created directories {target_subfolder}")

folder = source_folder / subcollection

for subfolder in folder.iterdir():
    if subfolder.is_dir():
        for file in find_datasets(subfolder):
            process_dataset(dm, i, file, name_prefix=subfolder.name)
            i += 1
dm.save()
# Out:
# #############
# # Processing sub-collection artificial
# #############
# Created directories /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial
# > Processing source dataset 0
#   skipped writing dataset 0 to disk, because it already exists.
#   skipped analyzing dataset 0, because metadata already exists.
# ... processed source dataset 0: -0_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.01_5.test.csv
# > Processing source dataset 1
#   skipped writing dataset 1 to disk, because it already exists.
#   skipped analyzing dataset 1, because metadata already exists.
# ... processed source dataset 1: -0_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_11.test.csv
# > Processing source dataset 2
#   skipped writing dataset 2 to disk, because it already exists.
#   skipped analyzing dataset 2, because metadata already exists.
# ... processed source dataset 2: -0_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_15.test.csv
# > Processing source dataset 3
#   skipped writing dataset 3 to disk, because it already exists.
#   skipped analyzing dataset 3, because metadata already exists.
# ... processed source dataset 3: -0_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_25.test.csv
# > Processing source dataset 4
#   skipped writing dataset 4 to disk, because it already exists.
#   skipped analyzing dataset 4, because metadata already exists.
# ... processed source dataset 4: -0_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_3.test.csv
# > Processing source dataset 5
#   skipped writing dataset 5 to disk, because it already exists.
#   skipped analyzing dataset 5, because metadata already exists.
# ... processed source dataset 5: -0_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_35.test.csv
# > Processing source dataset 6
#   skipped writing dataset 6 to disk, because it already exists.
#   skipped analyzing dataset 6, because metadata already exists.
# ... processed source dataset 6: -0_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_7.test.csv
# > Processing source dataset 7
#   skipped writing dataset 7 to disk, because it already exists.
#   skipped analyzing dataset 7, because metadata already exists.
# ... processed source dataset 7: -0_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-0_2_0.02_9.test.csv
# > Processing source dataset 8
#   skipped writing dataset 8 to disk, because it already exists.
#   skipped analyzing dataset 8, because metadata already exists.
# ... processed source dataset 8: -100_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.01_5.test.csv
# > Processing source dataset 9
#   skipped writing dataset 9 to disk, because it already exists.
#   skipped analyzing dataset 9, because metadata already exists.
# ... processed source dataset 9: -100_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_11.test.csv
# > Processing source dataset 10
#   skipped writing dataset 10 to disk, because it already exists.
#   skipped analyzing dataset 10, because metadata already exists.
# ... processed source dataset 10: -100_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_15.test.csv
# > Processing source dataset 11
#   skipped writing dataset 11 to disk, because it already exists.
#   skipped analyzing dataset 11, because metadata already exists.
# ... processed source dataset 11: -100_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_25.test.csv
# > Processing source dataset 12
#   skipped writing dataset 12 to disk, because it already exists.
#   skipped analyzing dataset 12, because metadata already exists.
# ... processed source dataset 12: -100_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_3.test.csv
# > Processing source dataset 13
#   skipped writing dataset 13 to disk, because it already exists.
#   skipped analyzing dataset 13, because metadata already exists.
# ... processed source dataset 13: -100_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_35.test.csv
# > Processing source dataset 14
#   skipped writing dataset 14 to disk, because it already exists.
#   skipped analyzing dataset 14, because metadata already exists.
# ... processed source dataset 14: -100_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_6.test.csv
# > Processing source dataset 15
#   skipped writing dataset 15 to disk, because it already exists.
#   skipped analyzing dataset 15, because metadata already exists.
# ... processed source dataset 15: -100_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_7.test.csv
# > Processing source dataset 16
#   skipped writing dataset 16 to disk, because it already exists.
#   skipped analyzing dataset 16, because metadata already exists.
# ... processed source dataset 16: -100_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-100_2_0.02_9.test.csv
# > Processing source dataset 17
#   skipped writing dataset 17 to disk, because it already exists.
#   skipped analyzing dataset 17, because metadata already exists.
# ... processed source dataset 17: -101_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.01_5.test.csv
# > Processing source dataset 18
#   skipped writing dataset 18 to disk, because it already exists.
#   skipped analyzing dataset 18, because metadata already exists.
# ... processed source dataset 18: -101_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_11.test.csv
# > Processing source dataset 19
#   skipped writing dataset 19 to disk, because it already exists.
#   skipped analyzing dataset 19, because metadata already exists.
# ... processed source dataset 19: -101_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_15.test.csv
# > Processing source dataset 20
#   skipped writing dataset 20 to disk, because it already exists.
#   skipped analyzing dataset 20, because metadata already exists.
# ... processed source dataset 20: -101_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_25.test.csv
# > Processing source dataset 21
#   skipped writing dataset 21 to disk, because it already exists.
#   skipped analyzing dataset 21, because metadata already exists.
# ... processed source dataset 21: -101_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_3.test.csv
# > Processing source dataset 22
#   skipped writing dataset 22 to disk, because it already exists.
#   skipped analyzing dataset 22, because metadata already exists.
# ... processed source dataset 22: -101_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_35.test.csv
# > Processing source dataset 23
#   skipped writing dataset 23 to disk, because it already exists.
#   skipped analyzing dataset 23, because metadata already exists.
# ... processed source dataset 23: -101_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_6.test.csv
# > Processing source dataset 24
#   skipped writing dataset 24 to disk, because it already exists.
#   skipped analyzing dataset 24, because metadata already exists.
# ... processed source dataset 24: -101_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_7.test.csv
# > Processing source dataset 25
#   skipped writing dataset 25 to disk, because it already exists.
#   skipped analyzing dataset 25, because metadata already exists.
# ... processed source dataset 25: -101_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-101_2_0.02_9.test.csv
# > Processing source dataset 26
#   skipped writing dataset 26 to disk, because it already exists.
#   skipped analyzing dataset 26, because metadata already exists.
# ... processed source dataset 26: -102_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.01_5.test.csv
# > Processing source dataset 27
#   skipped writing dataset 27 to disk, because it already exists.
#   skipped analyzing dataset 27, because metadata already exists.
# ... processed source dataset 27: -102_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_11.test.csv
# > Processing source dataset 28
#   skipped writing dataset 28 to disk, because it already exists.
#   skipped analyzing dataset 28, because metadata already exists.
# ... processed source dataset 28: -102_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_15.test.csv
# > Processing source dataset 29
#   skipped writing dataset 29 to disk, because it already exists.
#   skipped analyzing dataset 29, because metadata already exists.
# ... processed source dataset 29: -102_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_25.test.csv
# > Processing source dataset 30
#   skipped writing dataset 30 to disk, because it already exists.
#   skipped analyzing dataset 30, because metadata already exists.
# ... processed source dataset 30: -102_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_35.test.csv
# > Processing source dataset 31
#   skipped writing dataset 31 to disk, because it already exists.
#   skipped analyzing dataset 31, because metadata already exists.
# ... processed source dataset 31: -102_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_6.test.csv
# > Processing source dataset 32
#   skipped writing dataset 32 to disk, because it already exists.
#   skipped analyzing dataset 32, because metadata already exists.
# ... processed source dataset 32: -102_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_7.test.csv
# > Processing source dataset 33
#   skipped writing dataset 33 to disk, because it already exists.
#   skipped analyzing dataset 33, because metadata already exists.
# ... processed source dataset 33: -102_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-102_2_0.02_9.test.csv
# > Processing source dataset 34
#   skipped writing dataset 34 to disk, because it already exists.
#   skipped analyzing dataset 34, because metadata already exists.
# ... processed source dataset 34: -103_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-103_2_0.02_25.test.csv
# > Processing source dataset 35
#   skipped writing dataset 35 to disk, because it already exists.
#   skipped analyzing dataset 35, because metadata already exists.
# ... processed source dataset 35: -103_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-103_2_0.02_6.test.csv
# > Processing source dataset 36
#   skipped writing dataset 36 to disk, because it already exists.
#   skipped analyzing dataset 36, because metadata already exists.
# ... processed source dataset 36: -104_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.01_5.test.csv
# > Processing source dataset 37
#   skipped writing dataset 37 to disk, because it already exists.
#   skipped analyzing dataset 37, because metadata already exists.
# ... processed source dataset 37: -104_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_11.test.csv
# > Processing source dataset 38
#   skipped writing dataset 38 to disk, because it already exists.
#   skipped analyzing dataset 38, because metadata already exists.
# ... processed source dataset 38: -104_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_15.test.csv
# > Processing source dataset 39
#   skipped writing dataset 39 to disk, because it already exists.
#   skipped analyzing dataset 39, because metadata already exists.
# ... processed source dataset 39: -104_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_25.test.csv
# > Processing source dataset 40
#   skipped writing dataset 40 to disk, because it already exists.
#   skipped analyzing dataset 40, because metadata already exists.
# ... processed source dataset 40: -104_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_3.test.csv
# > Processing source dataset 41
#   skipped writing dataset 41 to disk, because it already exists.
#   skipped analyzing dataset 41, because metadata already exists.
# ... processed source dataset 41: -104_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_35.test.csv
# > Processing source dataset 42
#   skipped writing dataset 42 to disk, because it already exists.
#   skipped analyzing dataset 42, because metadata already exists.
# ... processed source dataset 42: -104_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_6.test.csv
# > Processing source dataset 43
#   skipped writing dataset 43 to disk, because it already exists.
#   skipped analyzing dataset 43, because metadata already exists.
# ... processed source dataset 43: -104_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_7.test.csv
# > Processing source dataset 44
#   skipped writing dataset 44 to disk, because it already exists.
#   skipped analyzing dataset 44, because metadata already exists.
# ... processed source dataset 44: -104_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-104_2_0.02_9.test.csv
# > Processing source dataset 45
#   skipped writing dataset 45 to disk, because it already exists.
#   skipped analyzing dataset 45, because metadata already exists.
# ... processed source dataset 45: -105_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.01_5.test.csv
# > Processing source dataset 46
#   skipped writing dataset 46 to disk, because it already exists.
#   skipped analyzing dataset 46, because metadata already exists.
# ... processed source dataset 46: -105_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_11.test.csv
# > Processing source dataset 47
#   skipped writing dataset 47 to disk, because it already exists.
#   skipped analyzing dataset 47, because metadata already exists.
# ... processed source dataset 47: -105_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_15.test.csv
# > Processing source dataset 48
#   skipped writing dataset 48 to disk, because it already exists.
#   skipped analyzing dataset 48, because metadata already exists.
# ... processed source dataset 48: -105_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_25.test.csv
# > Processing source dataset 49
#   skipped writing dataset 49 to disk, because it already exists.
#   skipped analyzing dataset 49, because metadata already exists.
# ... processed source dataset 49: -105_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_3.test.csv
# > Processing source dataset 50
#   skipped writing dataset 50 to disk, because it already exists.
#   skipped analyzing dataset 50, because metadata already exists.
# ... processed source dataset 50: -105_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_35.test.csv
# > Processing source dataset 51
#   skipped writing dataset 51 to disk, because it already exists.
#   skipped analyzing dataset 51, because metadata already exists.
# ... processed source dataset 51: -105_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_6.test.csv
# > Processing source dataset 52
#   skipped writing dataset 52 to disk, because it already exists.
#   skipped analyzing dataset 52, because metadata already exists.
# ... processed source dataset 52: -105_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_7.test.csv
# > Processing source dataset 53
#   skipped writing dataset 53 to disk, because it already exists.
#   skipped analyzing dataset 53, because metadata already exists.
# ... processed source dataset 53: -105_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-105_2_0.02_9.test.csv
# > Processing source dataset 54
#   skipped writing dataset 54 to disk, because it already exists.
#   skipped analyzing dataset 54, because metadata already exists.
# ... processed source dataset 54: -106_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.01_5.test.csv
# > Processing source dataset 55
#   skipped writing dataset 55 to disk, because it already exists.
#   skipped analyzing dataset 55, because metadata already exists.
# ... processed source dataset 55: -106_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_11.test.csv
# > Processing source dataset 56
#   skipped writing dataset 56 to disk, because it already exists.
#   skipped analyzing dataset 56, because metadata already exists.
# ... processed source dataset 56: -106_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_15.test.csv
# > Processing source dataset 57
#   skipped writing dataset 57 to disk, because it already exists.
#   skipped analyzing dataset 57, because metadata already exists.
# ... processed source dataset 57: -106_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_25.test.csv
# > Processing source dataset 58
#   skipped writing dataset 58 to disk, because it already exists.
#   skipped analyzing dataset 58, because metadata already exists.
# ... processed source dataset 58: -106_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_3.test.csv
# > Processing source dataset 59
#   skipped writing dataset 59 to disk, because it already exists.
#   skipped analyzing dataset 59, because metadata already exists.
# ... processed source dataset 59: -106_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_35.test.csv
# > Processing source dataset 60
#   skipped writing dataset 60 to disk, because it already exists.
#   skipped analyzing dataset 60, because metadata already exists.
# ... processed source dataset 60: -106_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_6.test.csv
# > Processing source dataset 61
#   skipped writing dataset 61 to disk, because it already exists.
#   skipped analyzing dataset 61, because metadata already exists.
# ... processed source dataset 61: -106_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_7.test.csv
# > Processing source dataset 62
#   skipped writing dataset 62 to disk, because it already exists.
#   skipped analyzing dataset 62, because metadata already exists.
# ... processed source dataset 62: -106_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-106_2_0.02_9.test.csv
# > Processing source dataset 63
#   skipped writing dataset 63 to disk, because it already exists.
#   skipped analyzing dataset 63, because metadata already exists.
# ... processed source dataset 63: -107_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.01_5.test.csv
# > Processing source dataset 64
#   skipped writing dataset 64 to disk, because it already exists.
#   skipped analyzing dataset 64, because metadata already exists.
# ... processed source dataset 64: -107_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_11.test.csv
# > Processing source dataset 65
#   skipped writing dataset 65 to disk, because it already exists.
#   skipped analyzing dataset 65, because metadata already exists.
# ... processed source dataset 65: -107_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_15.test.csv
# > Processing source dataset 66
#   skipped writing dataset 66 to disk, because it already exists.
#   skipped analyzing dataset 66, because metadata already exists.
# ... processed source dataset 66: -107_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_25.test.csv
# > Processing source dataset 67
#   skipped writing dataset 67 to disk, because it already exists.
#   skipped analyzing dataset 67, because metadata already exists.
# ... processed source dataset 67: -107_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_3.test.csv
# > Processing source dataset 68
#   skipped writing dataset 68 to disk, because it already exists.
#   skipped analyzing dataset 68, because metadata already exists.
# ... processed source dataset 68: -107_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_35.test.csv
# > Processing source dataset 69
#   skipped writing dataset 69 to disk, because it already exists.
#   skipped analyzing dataset 69, because metadata already exists.
# ... processed source dataset 69: -107_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_6.test.csv
# > Processing source dataset 70
#   skipped writing dataset 70 to disk, because it already exists.
#   skipped analyzing dataset 70, because metadata already exists.
# ... processed source dataset 70: -107_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_7.test.csv
# > Processing source dataset 71
#   skipped writing dataset 71 to disk, because it already exists.
#   skipped analyzing dataset 71, because metadata already exists.
# ... processed source dataset 71: -107_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-107_2_0.02_9.test.csv
# > Processing source dataset 72
#   skipped writing dataset 72 to disk, because it already exists.
#   skipped analyzing dataset 72, because metadata already exists.
# ... processed source dataset 72: -108_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.01_5.test.csv
# > Processing source dataset 73
#   skipped writing dataset 73 to disk, because it already exists.
#   skipped analyzing dataset 73, because metadata already exists.
# ... processed source dataset 73: -108_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_11.test.csv
# > Processing source dataset 74
#   skipped writing dataset 74 to disk, because it already exists.
#   skipped analyzing dataset 74, because metadata already exists.
# ... processed source dataset 74: -108_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_15.test.csv
# > Processing source dataset 75
#   skipped writing dataset 75 to disk, because it already exists.
#   skipped analyzing dataset 75, because metadata already exists.
# ... processed source dataset 75: -108_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_25.test.csv
# > Processing source dataset 76
#   skipped writing dataset 76 to disk, because it already exists.
#   skipped analyzing dataset 76, because metadata already exists.
# ... processed source dataset 76: -108_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_3.test.csv
# > Processing source dataset 77
#   skipped writing dataset 77 to disk, because it already exists.
#   skipped analyzing dataset 77, because metadata already exists.
# ... processed source dataset 77: -108_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_35.test.csv
# > Processing source dataset 78
#   skipped writing dataset 78 to disk, because it already exists.
#   skipped analyzing dataset 78, because metadata already exists.
# ... processed source dataset 78: -108_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_6.test.csv
# > Processing source dataset 79
#   skipped writing dataset 79 to disk, because it already exists.
#   skipped analyzing dataset 79, because metadata already exists.
# ... processed source dataset 79: -108_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_7.test.csv
# > Processing source dataset 80
#   skipped writing dataset 80 to disk, because it already exists.
#   skipped analyzing dataset 80, because metadata already exists.
# ... processed source dataset 80: -108_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-108_2_0.02_9.test.csv
# > Processing source dataset 81
#   skipped writing dataset 81 to disk, because it already exists.
#   skipped analyzing dataset 81, because metadata already exists.
# ... processed source dataset 81: -109_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-109_2_0.01_5.test.csv
# > Processing source dataset 82
#   skipped writing dataset 82 to disk, because it already exists.
#   skipped analyzing dataset 82, because metadata already exists.
# ... processed source dataset 82: -109_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-109_2_0.02_15.test.csv
# > Processing source dataset 83
#   skipped writing dataset 83 to disk, because it already exists.
#   skipped analyzing dataset 83, because metadata already exists.
# ... processed source dataset 83: -109_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-109_2_0.02_3.test.csv
# > Processing source dataset 84
#   skipped writing dataset 84 to disk, because it already exists.
#   skipped analyzing dataset 84, because metadata already exists.
# ... processed source dataset 84: -10_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.01_5.test.csv
# > Processing source dataset 85
#   skipped writing dataset 85 to disk, because it already exists.
#   skipped analyzing dataset 85, because metadata already exists.
# ... processed source dataset 85: -10_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_11.test.csv
# > Processing source dataset 86
#   skipped writing dataset 86 to disk, because it already exists.
#   skipped analyzing dataset 86, because metadata already exists.
# ... processed source dataset 86: -10_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_15.test.csv
# > Processing source dataset 87
#   skipped writing dataset 87 to disk, because it already exists.
#   skipped analyzing dataset 87, because metadata already exists.
# ... processed source dataset 87: -10_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_25.test.csv
# > Processing source dataset 88
#   skipped writing dataset 88 to disk, because it already exists.
#   skipped analyzing dataset 88, because metadata already exists.
# ... processed source dataset 88: -10_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_3.test.csv
# > Processing source dataset 89
#   skipped writing dataset 89 to disk, because it already exists.
#   skipped analyzing dataset 89, because metadata already exists.
# ... processed source dataset 89: -10_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_35.test.csv
# > Processing source dataset 90
#   skipped writing dataset 90 to disk, because it already exists.
#   skipped analyzing dataset 90, because metadata already exists.
# ... processed source dataset 90: -10_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_6.test.csv
# > Processing source dataset 91
#   skipped writing dataset 91 to disk, because it already exists.
#   skipped analyzing dataset 91, because metadata already exists.
# ... processed source dataset 91: -10_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_7.test.csv
# > Processing source dataset 92
#   skipped writing dataset 92 to disk, because it already exists.
#   skipped analyzing dataset 92, because metadata already exists.
# ... processed source dataset 92: -10_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-10_2_0.02_9.test.csv
# > Processing source dataset 93
#   skipped writing dataset 93 to disk, because it already exists.
#   skipped analyzing dataset 93, because metadata already exists.
# ... processed source dataset 93: -110_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.01_5.test.csv
# > Processing source dataset 94
#   skipped writing dataset 94 to disk, because it already exists.
#   skipped analyzing dataset 94, because metadata already exists.
# ... processed source dataset 94: -110_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_11.test.csv
# > Processing source dataset 95
#   skipped writing dataset 95 to disk, because it already exists.
#   skipped analyzing dataset 95, because metadata already exists.
# ... processed source dataset 95: -110_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_15.test.csv
# > Processing source dataset 96
#   skipped writing dataset 96 to disk, because it already exists.
#   skipped analyzing dataset 96, because metadata already exists.
# ... processed source dataset 96: -110_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_25.test.csv
# > Processing source dataset 97
#   skipped writing dataset 97 to disk, because it already exists.
#   skipped analyzing dataset 97, because metadata already exists.
# ... processed source dataset 97: -110_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_3.test.csv
# > Processing source dataset 98
#   skipped writing dataset 98 to disk, because it already exists.
#   skipped analyzing dataset 98, because metadata already exists.
# ... processed source dataset 98: -110_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_35.test.csv
# > Processing source dataset 99
#   skipped writing dataset 99 to disk, because it already exists.
#   skipped analyzing dataset 99, because metadata already exists.
# ... processed source dataset 99: -110_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_6.test.csv
# > Processing source dataset 100
#   skipped writing dataset 100 to disk, because it already exists.
#   skipped analyzing dataset 100, because metadata already exists.
# ... processed source dataset 100: -110_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_7.test.csv
# > Processing source dataset 101
#   skipped writing dataset 101 to disk, because it already exists.
#   skipped analyzing dataset 101, because metadata already exists.
# ... processed source dataset 101: -110_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-110_2_0.02_9.test.csv
# > Processing source dataset 102
#   skipped writing dataset 102 to disk, because it already exists.
#   skipped analyzing dataset 102, because metadata already exists.
# ... processed source dataset 102: -111_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.01_5.test.csv
# > Processing source dataset 103
#   skipped writing dataset 103 to disk, because it already exists.
#   skipped analyzing dataset 103, because metadata already exists.
# ... processed source dataset 103: -111_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_11.test.csv
# > Processing source dataset 104
#   skipped writing dataset 104 to disk, because it already exists.
#   skipped analyzing dataset 104, because metadata already exists.
# ... processed source dataset 104: -111_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_15.test.csv
# > Processing source dataset 105
#   skipped writing dataset 105 to disk, because it already exists.
#   skipped analyzing dataset 105, because metadata already exists.
# ... processed source dataset 105: -111_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_25.test.csv
# > Processing source dataset 106
#   skipped writing dataset 106 to disk, because it already exists.
#   skipped analyzing dataset 106, because metadata already exists.
# ... processed source dataset 106: -111_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_3.test.csv
# > Processing source dataset 107
#   skipped writing dataset 107 to disk, because it already exists.
#   skipped analyzing dataset 107, because metadata already exists.
# ... processed source dataset 107: -111_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_35.test.csv
# > Processing source dataset 108
#   skipped writing dataset 108 to disk, because it already exists.
#   skipped analyzing dataset 108, because metadata already exists.
# ... processed source dataset 108: -111_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_6.test.csv
# > Processing source dataset 109
#   skipped writing dataset 109 to disk, because it already exists.
#   skipped analyzing dataset 109, because metadata already exists.
# ... processed source dataset 109: -111_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_7.test.csv
# > Processing source dataset 110
#   skipped writing dataset 110 to disk, because it already exists.
#   skipped analyzing dataset 110, because metadata already exists.
# ... processed source dataset 110: -111_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-111_2_0.02_9.test.csv
# > Processing source dataset 111
#   skipped writing dataset 111 to disk, because it already exists.
#   skipped analyzing dataset 111, because metadata already exists.
# ... processed source dataset 111: -112_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.01_5.test.csv
# > Processing source dataset 112
#   skipped writing dataset 112 to disk, because it already exists.
#   skipped analyzing dataset 112, because metadata already exists.
# ... processed source dataset 112: -112_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_11.test.csv
# > Processing source dataset 113
#   skipped writing dataset 113 to disk, because it already exists.
#   skipped analyzing dataset 113, because metadata already exists.
# ... processed source dataset 113: -112_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_15.test.csv
# > Processing source dataset 114
#   skipped writing dataset 114 to disk, because it already exists.
#   skipped analyzing dataset 114, because metadata already exists.
# ... processed source dataset 114: -112_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_25.test.csv
# > Processing source dataset 115
#   skipped writing dataset 115 to disk, because it already exists.
#   skipped analyzing dataset 115, because metadata already exists.
# ... processed source dataset 115: -112_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_3.test.csv
# > Processing source dataset 116
#   skipped writing dataset 116 to disk, because it already exists.
#   skipped analyzing dataset 116, because metadata already exists.
# ... processed source dataset 116: -112_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_35.test.csv
# > Processing source dataset 117
#   skipped writing dataset 117 to disk, because it already exists.
#   skipped analyzing dataset 117, because metadata already exists.
# ... processed source dataset 117: -112_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_6.test.csv
# > Processing source dataset 118
#   skipped writing dataset 118 to disk, because it already exists.
#   skipped analyzing dataset 118, because metadata already exists.
# ... processed source dataset 118: -112_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_7.test.csv
# > Processing source dataset 119
#   skipped writing dataset 119 to disk, because it already exists.
#   skipped analyzing dataset 119, because metadata already exists.
# ... processed source dataset 119: -112_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-112_2_0.02_9.test.csv
# > Processing source dataset 120
#   skipped writing dataset 120 to disk, because it already exists.
#   skipped analyzing dataset 120, because metadata already exists.
# ... processed source dataset 120: -113_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.01_5.test.csv
# > Processing source dataset 121
#   skipped writing dataset 121 to disk, because it already exists.
#   skipped analyzing dataset 121, because metadata already exists.
# ... processed source dataset 121: -113_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_11.test.csv
# > Processing source dataset 122
#   skipped writing dataset 122 to disk, because it already exists.
#   skipped analyzing dataset 122, because metadata already exists.
# ... processed source dataset 122: -113_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_15.test.csv
# > Processing source dataset 123
#   skipped writing dataset 123 to disk, because it already exists.
#   skipped analyzing dataset 123, because metadata already exists.
# ... processed source dataset 123: -113_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_25.test.csv
# > Processing source dataset 124
#   skipped writing dataset 124 to disk, because it already exists.
#   skipped analyzing dataset 124, because metadata already exists.
# ... processed source dataset 124: -113_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_3.test.csv
# > Processing source dataset 125
#   skipped writing dataset 125 to disk, because it already exists.
#   skipped analyzing dataset 125, because metadata already exists.
# ... processed source dataset 125: -113_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_35.test.csv
# > Processing source dataset 126
#   skipped writing dataset 126 to disk, because it already exists.
#   skipped analyzing dataset 126, because metadata already exists.
# ... processed source dataset 126: -113_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_6.test.csv
# > Processing source dataset 127
#   skipped writing dataset 127 to disk, because it already exists.
#   skipped analyzing dataset 127, because metadata already exists.
# ... processed source dataset 127: -113_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_7.test.csv
# > Processing source dataset 128
#   skipped writing dataset 128 to disk, because it already exists.
#   skipped analyzing dataset 128, because metadata already exists.
# ... processed source dataset 128: -113_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-113_2_0.02_9.test.csv
# > Processing source dataset 129
#   skipped writing dataset 129 to disk, because it already exists.
#   skipped analyzing dataset 129, because metadata already exists.
# ... processed source dataset 129: -114_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.01_5.test.csv
# > Processing source dataset 130
#   skipped writing dataset 130 to disk, because it already exists.
#   skipped analyzing dataset 130, because metadata already exists.
# ... processed source dataset 130: -114_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_11.test.csv
# > Processing source dataset 131
#   skipped writing dataset 131 to disk, because it already exists.
#   skipped analyzing dataset 131, because metadata already exists.
# ... processed source dataset 131: -114_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_15.test.csv
# > Processing source dataset 132
#   skipped writing dataset 132 to disk, because it already exists.
#   skipped analyzing dataset 132, because metadata already exists.
# ... processed source dataset 132: -114_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_25.test.csv
# > Processing source dataset 133
#   skipped writing dataset 133 to disk, because it already exists.
#   skipped analyzing dataset 133, because metadata already exists.
# ... processed source dataset 133: -114_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_3.test.csv
# > Processing source dataset 134
#   skipped writing dataset 134 to disk, because it already exists.
#   skipped analyzing dataset 134, because metadata already exists.
# ... processed source dataset 134: -114_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_35.test.csv
# > Processing source dataset 135
#   skipped writing dataset 135 to disk, because it already exists.
#   skipped analyzing dataset 135, because metadata already exists.
# ... processed source dataset 135: -114_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_6.test.csv
# > Processing source dataset 136
#   skipped writing dataset 136 to disk, because it already exists.
#   skipped analyzing dataset 136, because metadata already exists.
# ... processed source dataset 136: -114_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_7.test.csv
# > Processing source dataset 137
#   skipped writing dataset 137 to disk, because it already exists.
#   skipped analyzing dataset 137, because metadata already exists.
# ... processed source dataset 137: -114_2_0.02_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-114_2_0.02_9.test.csv
# > Processing source dataset 138
#   skipped writing dataset 138 to disk, because it already exists.
#   skipped analyzing dataset 138, because metadata already exists.
# ... processed source dataset 138: -115_2_0.01_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.01_5.test.csv
# > Processing source dataset 139
#   skipped writing dataset 139 to disk, because it already exists.
#   skipped analyzing dataset 139, because metadata already exists.
# ... processed source dataset 139: -115_2_0.02_11.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_11.test.csv
# > Processing source dataset 140
#   skipped writing dataset 140 to disk, because it already exists.
#   skipped analyzing dataset 140, because metadata already exists.
# ... processed source dataset 140: -115_2_0.02_15.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_15.test.csv
# > Processing source dataset 141
#   skipped writing dataset 141 to disk, because it already exists.
#   skipped analyzing dataset 141, because metadata already exists.
# ... processed source dataset 141: -115_2_0.02_25.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_25.test.csv
# > Processing source dataset 142
#   skipped writing dataset 142 to disk, because it already exists.
#   skipped analyzing dataset 142, because metadata already exists.
# ... processed source dataset 142: -115_2_0.02_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_3.test.csv
# > Processing source dataset 143
#   skipped writing dataset 143 to disk, because it already exists.
#   skipped analyzing dataset 143, because metadata already exists.
# ... processed source dataset 143: -115_2_0.02_35.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_35.test.csv
# > Processing source dataset 144
#   skipped writing dataset 144 to disk, because it already exists.
#   skipped analyzing dataset 144, because metadata already exists.
# ... processed source dataset 144: -115_2_0.02_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_6.test.csv
# > Processing source dataset 145
#   skipped writing dataset 145 to disk, because it already exists.
#   skipped analyzing dataset 145, because metadata already exists.
# ... processed source dataset 145: -115_2_0.02_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-artificial/-115_2_0.02_7.test.csv
# > Processing source dataset 146
#   skipped writing dataset 146 to disk, because it already exists.
#   skipped analyzing dataset 146, because metadata already exists.
# ...
# > Processing source dataset 12105
#   skipped writing dataset 12105 to disk, because it already exists.
#   skipped analyzing dataset 12105, because metadata already exists.
# ... processed source dataset 12105: NAB_add_point_outlier_0.02-NAB_data_KnownCause_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_KnownCause_5.test.csv
# > Processing source dataset 12106
#   skipped writing dataset 12106 to disk, because it already exists.
#   skipped analyzing dataset 12106, because metadata already exists.
# ... processed source dataset 12106: NAB_add_point_outlier_0.02-NAB_data_KnownCause_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_KnownCause_6.test.csv
# > Processing source dataset 12107
#   skipped writing dataset 12107 to disk, because it already exists.
#   skipped analyzing dataset 12107, because metadata already exists.
# ... processed source dataset 12107: NAB_add_point_outlier_0.02-NAB_data_KnownCause_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_KnownCause_7.test.csv
# > Processing source dataset 12108
#   skipped writing dataset 12108 to disk, because it already exists.
#   skipped analyzing dataset 12108, because metadata already exists.
# ... processed source dataset 12108: NAB_add_point_outlier_0.02-NAB_data_Traffic_1.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_1.test.csv
# > Processing source dataset 12109
#   skipped writing dataset 12109 to disk, because it already exists.
#   skipped analyzing dataset 12109, because metadata already exists.
# ... processed source dataset 12109: NAB_add_point_outlier_0.02-NAB_data_Traffic_2.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_2.test.csv
# > Processing source dataset 12110
#   skipped writing dataset 12110 to disk, because it already exists.
#   skipped analyzing dataset 12110, because metadata already exists.
# ... processed source dataset 12110: NAB_add_point_outlier_0.02-NAB_data_Traffic_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_3.test.csv
# > Processing source dataset 12111
#   skipped writing dataset 12111 to disk, because it already exists.
#   skipped analyzing dataset 12111, because metadata already exists.
# ... processed source dataset 12111: NAB_add_point_outlier_0.02-NAB_data_Traffic_4.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_4.test.csv
# > Processing source dataset 12112
#   skipped writing dataset 12112 to disk, because it already exists.
#   skipped analyzing dataset 12112, because metadata already exists.
# ... processed source dataset 12112: NAB_add_point_outlier_0.02-NAB_data_Traffic_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_5.test.csv
# > Processing source dataset 12113
#   skipped writing dataset 12113 to disk, because it already exists.
#   skipped analyzing dataset 12113, because metadata already exists.
# ... processed source dataset 12113: NAB_add_point_outlier_0.02-NAB_data_Traffic_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_6.test.csv
# > Processing source dataset 12114
#   skipped writing dataset 12114 to disk, because it already exists.
#   skipped analyzing dataset 12114, because metadata already exists.
# ... processed source dataset 12114: NAB_add_point_outlier_0.02-NAB_data_Traffic_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_Traffic_7.test.csv
# > Processing source dataset 12115
#   skipped writing dataset 12115 to disk, because it already exists.
#   skipped analyzing dataset 12115, because metadata already exists.
# ... processed source dataset 12115: NAB_add_point_outlier_0.02-NAB_data_art0_0.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art0_0.test.csv
# > Processing source dataset 12116
#   skipped writing dataset 12116 to disk, because it already exists.
#   skipped analyzing dataset 12116, because metadata already exists.
# ... processed source dataset 12116: NAB_add_point_outlier_0.02-NAB_data_art0_1.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art0_1.test.csv
# > Processing source dataset 12117
#   skipped writing dataset 12117 to disk, because it already exists.
#   skipped analyzing dataset 12117, because metadata already exists.
# ... processed source dataset 12117: NAB_add_point_outlier_0.02-NAB_data_art0_2.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art0_2.test.csv
# > Processing source dataset 12118
#   skipped writing dataset 12118 to disk, because it already exists.
#   skipped analyzing dataset 12118, because metadata already exists.
# ... processed source dataset 12118: NAB_add_point_outlier_0.02-NAB_data_art0_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art0_3.test.csv
# > Processing source dataset 12119
#   skipped writing dataset 12119 to disk, because it already exists.
#   skipped analyzing dataset 12119, because metadata already exists.
# ... processed source dataset 12119: NAB_add_point_outlier_0.02-NAB_data_art0_4.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art0_4.test.csv
# > Processing source dataset 12120
#   skipped writing dataset 12120 to disk, because it already exists.
#   skipped analyzing dataset 12120, because metadata already exists.
# ... processed source dataset 12120: NAB_add_point_outlier_0.02-NAB_data_art1_0.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_0.test.csv
# > Processing source dataset 12121
#   skipped writing dataset 12121 to disk, because it already exists.
#   skipped analyzing dataset 12121, because metadata already exists.
# ... processed source dataset 12121: NAB_add_point_outlier_0.02-NAB_data_art1_1.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_1.test.csv
# > Processing source dataset 12122
#   skipped writing dataset 12122 to disk, because it already exists.
#   skipped analyzing dataset 12122, because metadata already exists.
# ... processed source dataset 12122: NAB_add_point_outlier_0.02-NAB_data_art1_2.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_2.test.csv
# > Processing source dataset 12123
#   skipped writing dataset 12123 to disk, because it already exists.
#   skipped analyzing dataset 12123, because metadata already exists.
# ... processed source dataset 12123: NAB_add_point_outlier_0.02-NAB_data_art1_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_3.test.csv
# > Processing source dataset 12124
#   skipped writing dataset 12124 to disk, because it already exists.
#   skipped analyzing dataset 12124, because metadata already exists.
# ... processed source dataset 12124: NAB_add_point_outlier_0.02-NAB_data_art1_4.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_4.test.csv
# > Processing source dataset 12125
#   skipped writing dataset 12125 to disk, because it already exists.
#   skipped analyzing dataset 12125, because metadata already exists.
# ... processed source dataset 12125: NAB_add_point_outlier_0.02-NAB_data_art1_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_art1_5.test.csv
# > Processing source dataset 12126
#   skipped writing dataset 12126 to disk, because it already exists.
#   skipped analyzing dataset 12126, because metadata already exists.
# ... processed source dataset 12126: NAB_add_point_outlier_0.02-NAB_data_tweets_1.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_1.test.csv
# > Processing source dataset 12127
#   skipped writing dataset 12127 to disk, because it already exists.
#   skipped analyzing dataset 12127, because metadata already exists.
# ... processed source dataset 12127: NAB_add_point_outlier_0.02-NAB_data_tweets_10.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_10.test.csv
# > Processing source dataset 12128
#   skipped writing dataset 12128 to disk, because it already exists.
#   skipped analyzing dataset 12128, because metadata already exists.
# ... processed source dataset 12128: NAB_add_point_outlier_0.02-NAB_data_tweets_2.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_2.test.csv
# > Processing source dataset 12129
#   skipped writing dataset 12129 to disk, because it already exists.
#   skipped analyzing dataset 12129, because metadata already exists.
# ... processed source dataset 12129: NAB_add_point_outlier_0.02-NAB_data_tweets_3.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_3.test.csv
# > Processing source dataset 12130
#   skipped writing dataset 12130 to disk, because it already exists.
#   skipped analyzing dataset 12130, because metadata already exists.
# ... processed source dataset 12130: NAB_add_point_outlier_0.02-NAB_data_tweets_4.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_4.test.csv
# > Processing source dataset 12131
#   skipped writing dataset 12131 to disk, because it already exists.
#   skipped analyzing dataset 12131, because metadata already exists.
# ... processed source dataset 12131: NAB_add_point_outlier_0.02-NAB_data_tweets_5.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_5.test.csv
# > Processing source dataset 12132
#   skipped writing dataset 12132 to disk, because it already exists.
#   skipped analyzing dataset 12132, because metadata already exists.
# ... processed source dataset 12132: NAB_add_point_outlier_0.02-NAB_data_tweets_6.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_6.test.csv
# > Processing source dataset 12133
#   skipped writing dataset 12133 to disk, because it already exists.
#   skipped analyzing dataset 12133, because metadata already exists.
# ... processed source dataset 12133: NAB_add_point_outlier_0.02-NAB_data_tweets_7.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_7.test.csv
# > Processing source dataset 12134
#   skipped writing dataset 12134 to disk, because it already exists.
#   skipped analyzing dataset 12134, because metadata already exists.
# ... processed source dataset 12134: NAB_add_point_outlier_0.02-NAB_data_tweets_8.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_8.test.csv
# > Processing source dataset 12135
#   skipped writing dataset 12135 to disk, because it already exists.
#   skipped analyzing dataset 12135, because metadata already exists.
# ... processed source dataset 12135: NAB_add_point_outlier_0.02-NAB_data_tweets_9.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/NAB_add_point_outlier_0.02-NAB_data_tweets_9.test.csv
# > Processing source dataset 12136
#   skipped writing dataset 12136 to disk, because it already exists.
#   skipped analyzing dataset 12136, because metadata already exists.
# ... processed source dataset 12136: MGAB_add_white_noise_1-1.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-1.test.test.csv
# > Processing source dataset 12137
#   skipped writing dataset 12137 to disk, because it already exists.
#   skipped analyzing dataset 12137, because metadata already exists.
# ... processed source dataset 12137: MGAB_add_white_noise_1-10.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-10.test.test.csv
# > Processing source dataset 12138
#   skipped writing dataset 12138 to disk, because it already exists.
#   skipped analyzing dataset 12138, because metadata already exists.
# ... processed source dataset 12138: MGAB_add_white_noise_1-2.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-2.test.test.csv
# > Processing source dataset 12139
#   skipped writing dataset 12139 to disk, because it already exists.
#   skipped analyzing dataset 12139, because metadata already exists.
# ... processed source dataset 12139: MGAB_add_white_noise_1-3.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-3.test.test.csv
# > Processing source dataset 12140
#   skipped writing dataset 12140 to disk, because it already exists.
#   skipped analyzing dataset 12140, because metadata already exists.
# ... processed source dataset 12140: MGAB_add_white_noise_1-4.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-4.test.test.csv
# > Processing source dataset 12141
#   skipped writing dataset 12141 to disk, because it already exists.
#   skipped analyzing dataset 12141, because metadata already exists.
# ... processed source dataset 12141: MGAB_add_white_noise_1-5.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-5.test.test.csv
# > Processing source dataset 12142
#   skipped writing dataset 12142 to disk, because it already exists.
#   skipped analyzing dataset 12142, because metadata already exists.
# ... processed source dataset 12142: MGAB_add_white_noise_1-6.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-6.test.test.csv
# > Processing source dataset 12143
#   skipped writing dataset 12143 to disk, because it already exists.
#   skipped analyzing dataset 12143, because metadata already exists.
# ... processed source dataset 12143: MGAB_add_white_noise_1-7.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-7.test.test.csv
# > Processing source dataset 12144
#   skipped writing dataset 12144 to disk, because it already exists.
#   skipped analyzing dataset 12144, because metadata already exists.
# ... processed source dataset 12144: MGAB_add_white_noise_1-8.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-8.test.test.csv
# > Processing source dataset 12145
#   skipped writing dataset 12145 to disk, because it already exists.
#   skipped analyzing dataset 12145, because metadata already exists.
# ... processed source dataset 12145: MGAB_add_white_noise_1-9.test.out -> /home/projects/akita/data/benchmark-data/data-processed/univariate/TSB-UAD-synthetic/MGAB_add_white_noise_1-9.test.test.csv

# %%
dm.refresh()
dm.df().loc[(slice(dataset_collection_name,dataset_collection_name), slice(None))]
# Out:
#                                                                   train_path  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                              NaN
#                 -0_2_0.02_11                                             NaN
#                 -0_2_0.02_15                                             NaN
#                 -0_2_0.02_25                                             NaN
#                 -0_2_0.02_3                                              NaN
# ...                                                                      ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data        NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data        NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data        NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data        NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data         NaN
#
#                                                                                                            test_path  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                        univariate/TSB-UAD-artificial/-0_2_0.01_5.test...
#                 -0_2_0.02_11                                       univariate/TSB-UAD-artificial/-0_2_0.02_11.tes...
#                 -0_2_0.02_15                                       univariate/TSB-UAD-artificial/-0_2_0.02_15.tes...
#                 -0_2_0.02_25                                       univariate/TSB-UAD-artificial/-0_2_0.02_25.tes...
#                 -0_2_0.02_3                                        univariate/TSB-UAD-artificial/-0_2_0.02_3.test...
# ...                                                                                                              ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data  univariate/TSB-UAD-synthetic/YAHOO_flip_segmen...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data  univariate/TSB-UAD-synthetic/YAHOO_flip_segmen...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data  univariate/TSB-UAD-synthetic/YAHOO_flip_segmen...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data  univariate/TSB-UAD-synthetic/YAHOO_flip_segmen...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data   univariate/TSB-UAD-synthetic/YAHOO_flip_segmen...
#
#                                                                   dataset_type  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                          synthetic
#                 -0_2_0.02_11                                         synthetic
#                 -0_2_0.02_15                                         synthetic
#                 -0_2_0.02_25                                         synthetic
#                 -0_2_0.02_3                                          synthetic
# ...                                                                        ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data    synthetic
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data    synthetic
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data    synthetic
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data    synthetic
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data     synthetic
#
#                                                                    datetime_index  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                 False
#                 -0_2_0.02_11                                                False
#                 -0_2_0.02_15                                                False
#                 -0_2_0.02_25                                                False
#                 -0_2_0.02_3                                                 False
# ...                                                                           ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data           False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data           False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data           False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data           False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data            False
#
#                                                                    split_at  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                             NaN
#                 -0_2_0.02_11                                            NaN
#                 -0_2_0.02_15                                            NaN
#                 -0_2_0.02_25                                            NaN
#                 -0_2_0.02_3                                             NaN
# ...                                                                     ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data       NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data       NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data       NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data       NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data        NaN
#
#                                                                      train_type  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                        unsupervised
#                 -0_2_0.02_11                                       unsupervised
#                 -0_2_0.02_15                                       unsupervised
#                 -0_2_0.02_25                                       unsupervised
#                 -0_2_0.02_3                                        unsupervised
# ...                                                                         ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data  unsupervised
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data  unsupervised
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data  unsupervised
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data  unsupervised
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data   unsupervised
#
#                                                                    train_is_normal  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                  False
#                 -0_2_0.02_11                                                 False
#                 -0_2_0.02_15                                                 False
#                 -0_2_0.02_25                                                 False
#                 -0_2_0.02_3                                                  False
# ...                                                                            ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data            False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data            False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data            False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data            False
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data             False
#
#                                                                    input_type  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                        univariate
#                 -0_2_0.02_11                                       univariate
#                 -0_2_0.02_15                                       univariate
#                 -0_2_0.02_25                                       univariate
#                 -0_2_0.02_3                                        univariate
# ...                                                                       ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data  univariate
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data  univariate
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data  univariate
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data  univariate
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data   univariate
#
#                                                                    length  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                        102500
#                 -0_2_0.02_11                                        51000
#                 -0_2_0.02_15                                        52000
#                 -0_2_0.02_25                                        52000
#                 -0_2_0.02_3                                         51000
# ...                                                                   ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data    1421
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data    1421
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data    1421
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data    1421
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data     1421
#
#                                                                    dimensions  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                 1
#                 -0_2_0.02_11                                                1
#                 -0_2_0.02_15                                                1
#                 -0_2_0.02_25                                                1
#                 -0_2_0.02_3                                                 1
# ...                                                                       ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data           1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data           1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data           1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data           1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data            1
#
#                                                                    contamination  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                             0.009756
#                 -0_2_0.02_11                                            0.019608
#                 -0_2_0.02_15                                            0.019231
#                 -0_2_0.02_25                                            0.019231
#                 -0_2_0.02_3                                             0.019608
# ...                                                                          ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data       0.000704
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data       0.066151
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data       0.078114
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data       0.000704
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data        0.000704
#
#                                                                    num_anomalies  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                    2
#                 -0_2_0.02_11                                                   2
#                 -0_2_0.02_15                                                   2
#                 -0_2_0.02_25                                                   2
#                 -0_2_0.02_3                                                    2
# ...                                                                          ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data              1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data              2
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data              5
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data              1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data               1
#
#                                                                    min_anomaly_length  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                       500
#                 -0_2_0.02_11                                                      500
#                 -0_2_0.02_15                                                      500
#                 -0_2_0.02_25                                                      500
#                 -0_2_0.02_3                                                       500
# ...                                                                               ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data                   1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data                   2
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data                   3
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data                   1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data                    1
#
#                                                                    median_anomaly_length  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                          500
#                 -0_2_0.02_11                                                         500
#                 -0_2_0.02_15                                                         500
#                 -0_2_0.02_25                                                         500
#                 -0_2_0.02_3                                                          500
# ...                                                                                  ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data                      1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data                     47
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data                     35
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data                      1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data                       1
#
#                                                                    max_anomaly_length  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                       500
#                 -0_2_0.02_11                                                      500
#                 -0_2_0.02_15                                                      500
#                 -0_2_0.02_25                                                      500
#                 -0_2_0.02_3                                                       500
# ...                                                                               ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data                   1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data                  92
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data                  35
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data                   1
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data                    1
#
#                                                                            mean  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                       -4.704967e-08
#                 -0_2_0.02_11                                      -2.467229e-08
#                 -0_2_0.02_15                                       5.153077e-08
#                 -0_2_0.02_25                                       8.580385e-09
#                 -0_2_0.02_3                                       -4.574078e-08
# ...                                                                         ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data  1.698696e+03
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data  7.896721e+03
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data  3.117098e+04
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data  1.899806e+03
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data   1.922217e+03
#
#                                                                          stddev  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                            0.999004
#                 -0_2_0.02_11                                           0.999009
#                 -0_2_0.02_15                                           0.999008
#                 -0_2_0.02_25                                           0.999008
#                 -0_2_0.02_3                                            0.999010
# ...                                                                         ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data   1393.604830
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data   4823.921229
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data  18205.681520
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data   1456.487365
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data    1466.295113
#
#                                                                              trend  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                               no trend
#                 -0_2_0.02_11                                              no trend
#                 -0_2_0.02_15                                              no trend
#                 -0_2_0.02_25                                              no trend
#                 -0_2_0.02_3                                               no trend
# ...                                                                            ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data         no trend
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data      kubic trend
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data      kubic trend
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data         no trend
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data   quadratic trend
#
#                                                                             stationarity  \
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                        difference_stationary
#                 -0_2_0.02_11                                       difference_stationary
#                 -0_2_0.02_15                                       difference_stationary
#                 -0_2_0.02_25                                       difference_stationary
#                 -0_2_0.02_3                                        difference_stationary
# ...                                                                                  ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data             stationary
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data       trend_stationary
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data       trend_stationary
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data       trend_stationary
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data              stationary
#
#                                                                    period_size
# collection_name dataset_name
# TSB-UAD         -0_2_0.01_5                                                NaN
#                 -0_2_0.02_11                                               NaN
#                 -0_2_0.02_15                                               NaN
#                 -0_2_0.02_25                                               NaN
#                 -0_2_0.02_3                                                NaN
# ...                                                                        ...
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_96_data          NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_97_data          NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_98_data          NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_99_data          NaN
#                 YAHOO_flip_segment_0.08-Yahoo_A2synthetic_9_data           NaN
#
# [15051 rows x 20 columns]

# %% [markdown]
# ## Exploration

# %%
folder = source_folder / "artificial"
datasets = find_datasets(folder)
[d.name for d in datasets]
# Out:
# ['0_2_0.01_5.out',
#  '0_2_0.02_11.out',
#  '0_2_0.02_15.out',
#  '0_2_0.02_25.out',
#  '0_2_0.02_3.out',
#  '0_2_0.02_35.out',
#  '0_2_0.02_7.out',
#  '0_2_0.02_9.out',
#  '100_2_0.01_5.out',
#  '100_2_0.02_11.out',
#  '100_2_0.02_15.out',
#  '100_2_0.02_25.out',
#  '100_2_0.02_3.out',
#  '100_2_0.02_35.out',
#  '100_2_0.02_6.out',
#  '100_2_0.02_7.out',
#  '100_2_0.02_9.out',
#  '101_2_0.01_5.out',
#  '8_2_0.02_6.out',
#  '8_2_0.02_7.out',
#  '8_2_0.02_9.out',
#  '90_2_0.01_5.out',
#  '90_2_0.02_11.out',
#  '90_2_0.02_15.out',
#  '90_2_0.02_25.out',
#  '90_2_0.02_3.out',
#  '90_2_0.02_35.out',
#  '90_2_0.02_6.out',
#  '90_2_0.02_7.out',
#  '90_2_0.02_9.out',
#  '91_2_0.01_5.out',
#  '91_2_0.02_11.out',
#  '91_2_0.02_15.out',
#  '91_2_0.02_25.out',
#  '91_2_0.02_3.out',
#  '91_2_0.02_35.out',
#  '91_2_0.02_6.out',
#  '91_2_0.02_9.out',
#  '92_2_0.02_11.out',
#  '92_2_0.02_15.out',
#  '92_2_0.02_3.out',
#  '92_2_0.02_35.out',
#  '92_2_0.02_7.out',
#  '92_2_0.02_9.out',
#  '93_2_0.01_5.out',
#  '93_2_0.02_11.out',
#  '93_2_0.02_15.out',
#  '93_2_0.02_25.out',
#  '93_2_0.02_3.out',
#  '93_2_0.02_35.out',
#  '93_2_0.02_6.out',
#  '93_2_0.02_7.out',
#  '93_2_0.02_9.out',
#  '94_2_0.01_5.out',
#  '94_2_0.02_11.out',
#  '94_2_0.02_3.out',
#  '94_2_0.02_35.out',
#  '94_2_0.02_6.out',
#  '94_2_0.02_7.out',
#  '94_2_0.02_9.out',
#  '95_2_0.01_5.out',
#  '95_2_0.02_11.out',
#  '95_2_0.02_15.out',
#  '95_2_0.02_25.out',
#  '95_2_0.02_3.out',
#  '95_2_0.02_35.out',
#  '95_2_0.02_6.out',
#  '95_2_0.02_7.out',
#  '95_2_0.02_9.out',
#  '96_2_0.02_11.out',
#  '97_2_0.01_5.out',
#  '97_2_0.02_11.out',
#  '97_2_0.02_15.out',
#  '97_2_0.02_25.out',
#  '97_2_0.02_35.out',
#  '97_2_0.02_6.out',
#  '97_2_0.02_9.out',
#  '98_2_0.01_5.out',
#  '98_2_0.02_11.out',
#  '98_2_0.02_3.out',
#  '98_2_0.02_35.out',
#  '98_2_0.02_7.out',
#  '98_2_0.02_9.out',
#  '99_2_0.01_5.out',
#  '99_2_0.02_15.out',
#  '9_2_0.01_5.out',
#  '9_2_0.02_11.out',
#  '9_2_0.02_15.out',
#  '9_2_0.02_25.out',
#  '9_2_0.02_3.out',
#  '9_2_0.02_35.out',
#  '9_2_0.02_6.out',
#  '9_2_0.02_7.out',
#  '9_2_0.02_9.out']

# %%
f = datasets[10]
df = pd.read_csv(f, header=None)
df.columns = ["value", "is_anomaly"]
df.insert(0, "timestamp", df.index)
df
# Out:
#        timestamp     value  is_anomaly
# 0              0 -0.078919           0
# 1              1  0.128840           0
# 2              2  0.159690           0
# 3              3  0.085734           0
# 4              4  0.001960           0
# ...          ...       ...         ...
# 39265      39265 -0.776240           0
# 39266      39266 -0.775480           0
# 39267      39267 -0.784340           0
# 39268      39268 -0.774420           0
# 39269      39269 -0.729400           0
#
# [39270 rows x 3 columns]

# %%
df.plot(subplots=True)
# plt.xlim(anomaly[0]-1500, anomaly[1]+1500)
plt.show()
